# %% [markdown]
# # API Scavenger Hunt! 👀
#
# ## Introduction 👋
# In this lab, you will learn the fundamentals of working with APIs as a data analyst by making `requests` to an API and formatting the `response` data appropriately. Each task will offer a different challenge, such as:
#
# - working with different request parameters and query parameters,
# - using API keys and tokens, and
# - eventually signing up for and making requests from the Open Weather Map API, then exporting data from that request to JSON and importing the JSON into Tableau.
#
# ## Resources 📕
# We recommend having the following Student Hub articles open while making your requests
# - [RESTful APIs](https://devcodecamp.helpkit.so/definitions-examples-and-frequently-asked-questions/vUgiURdNAgva1AaaH99uBY/rest-apis/oN6ZdGaNop8f52gx43kTj6)
# - [Importing & Exporting JSON with Pandas](https://devcodecamp.helpkit.so/definitions-examples-and-frequently-asked-questions/vUgiURdNAgva1AaaH99uBY/importing--exporting-data-with-pandas/3gXNpDMk4fkWP6zdepRCod#json-files)

# %% [markdown]
# ---
# ## Task 0: Imports
# ---
# - ✅ In the code block below, import the `requests`, `pandas`, and `json` packages
#     - > 👉🏼 The imports should be written as three different lines. Don't forget the alias for Pandas!

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ---
# ## Task 1: Current Forecast
# ---
# The Open Weather Map API is a popular, open source API for weather forecasts that includes future weather, historical weather data, pollution and air quality forecasting, and more!
#
# For the purpose of this lab, we will focus on two main features of Open Weather Map API:
# - Current Weather Data
# - 5 Day / 3 Hour Forecast Data
#
# We'll use this API to get practice with basic API usage and documentation parsing.
#
# ### Subtask 1: Create Open Weather Map API Account & Obtain Key
# - ✅ Navigate to the following website and locate the `Sign In` page: 👉🏼 [Open Weather Map API](https://openweathermap.org/) 👈🏻
#     - Click the option to **Create a new account**
# - ✅ After creating your account, check your email for a verification message from Open Weather Map API
# - ✅ Locate the API Key (Select your username in the top right --> My API Keys) and set it equal to a variable called `key` in the code block below. (Make sure it is a string!)

# %%
key = "5c49e7681b61771037d8534bf96691ed"

# %% [markdown]
# ### Subtask 2: Calculate Latitude & Longitude of Your Location
# - ✅ Navigate to the following website: 👉🏼 [GPS Coordinates](https://www.gps-coordinates.net/my-location) 👈🏻
# - ✅ When prompted, allow the browser to access your current location
# - ✅ Note the values for Latitude and Longitude, and set them equal to the variables called `lat` and `lon` in the code block below. (Make sure it is a number!)

# %%
lat = 25.351
lon = 41.98

# My GPS Coordinates at https://www.gps-coordinates.net/my-location

# %% [markdown]
# ### Subtask 3: Generate Request URL
# TODO
# - ✅ Navigate to the following website  👉🏼 [API Documentation](https://openweathermap.org/api) 👈🏻
# - ✅ Locate the documentation for the **Current Weather Data** API
# - ✅ Copy the URL for this API, and store it in the `url` variable below.  Use a **Python f string** to insert your latitude, longitude, and API key values into the URL

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={key}"

# %% [markdown]
# ### Subtask 4: GET your current weather forecast.
# TODO
# - ✅ Use the above URL to make a GET request, and save the result as a variable
# - ✅ "Prettify" the response & print it out, then open the output in a text editor for easy reference.
#     - > Use that output to answer the questions in the Markdown block below

# %%
response = requests.get(url).json()
prettified_response = json.dumps(response, indent=4, skipkeys=True)
print(prettified_response)

# Code Demo - APIs & JSON in Action 18:00
# Out:
# {
#     "coord": {
#         "lon": 41.98,
#         "lat": 25.351
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.46,
#         "feels_like": 294.95,
#         "temp_min": 295.46,
#         "temp_max": 295.46,
#         "pressure": 1015,
#         "humidity": 46,
#         "sea_level": 1015,
#         "grnd_level": 923
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.19,
#         "deg": 49,
#         "gust": 10.3
#     },
#     "clouds": {
#         "all": 94
#     },
#     "dt": 1680889541,
#     "sys": {
#         "country": "SA",
#         "sunrise": 1680836264,
#         "sunset": 1680881434
#     },
#     "timezone": 10800,
#     "id": 396460,
#     "name": "Khushayb\u012b al \u1e28a\u1e11ar",
#     "cod": 200
# }

# %% [markdown]
# QUESTION 1
# - ❓ What is the **wind speed** for your current location?
# - 🅰️: "speed": 7.07
#
# QUESTION 2
# - ❓ How would you access the value for **wind speed** within this response?
# - 🅰️: `wind_speed = section["speed"]`
#
# QUESTION 3
# - ❓ What is the **weather description** for your current location?
# - 🅰️: "description": "clear sky"
#
# QUESTION 4
# - ❓ How would you access the value for **weather description** within this response?
# - 🅰️: `weather_description = section["description"]`

# %% [markdown]
# ---
# ## Task 2: 5 Day / 3 Hour Forecast
# ---
#
# ### Subtask 1: Find the Forecast URL
# Todo
# - ✅ Navigate to the following website  👉🏼 [API Documentation](https://openweathermap.org/api) 👈🏻
# - ✅ Locate the documentation for the **5 Day / 3 Hour Forecast** API
# - ✅ Copy the URL for this API, and store it in the `forecast_url` variable below.  Use a **Python f string** to insert your latitude, longitude, and API key values into the URL
# - ✅ Add the following additional parameter to the **end** of `forecast_url`, to convert temperature to Fahrenheit
#     - > **`&units=imperial`**

# %%
forecast_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={key}"

# %% [markdown]
# ### Subtask 2: GET your 5-day weather forecast.
# TODO
# - ✅ Use the above URL to make a GET request, and save the result as a variable
# - ✅ "Prettify" the response & print it out, then open the output in a text editor for easy reference.

# %%
forecast = requests.get(forecast_url).json()
prettified_forecast = json.dumps(forecast, indent=4, skipkeys=True)
print(prettified_forecast)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1680890400,
#             "main": {
#                 "temp": 295.46,
#                 "feels_like": 294.95,
#                 "temp_min": 295.46,
#                 "temp_max": 295.46,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 923,
#                 "humidity": 46,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 94
#             },
#             "wind": {
#                 "speed": 7.19,
#                 "deg": 49,
#                 "gust": 10.3
#             },
#             "visibility": 10000,
#             "pop": 0.38,
#             "rain": {
#                 "3h": 0.15
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-07 18:00:00"
#         },
#         {
#             "dt": 1680901200,
#             "main": {
#                 "temp": 294.77,
#                 "feels_like": 294.29,
#                 "temp_min": 293.38,
#                 "temp_max": 294.77,
#                 "pressure": 1015,
#                 "sea_level": 1015,
#                 "grnd_level": 924,
#                 "humidity": 50,
#                 "temp_kf": 1.39
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 7.45,
#                 "deg": 59,
#                 "gust": 10.33
#             },
#             "visibility": 10000,
#             "pop": 0.63,
#             "rain": {
#                 "3h": 1
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-07 21:00:00"
#         },
#         {
#             "dt": 1680912000,
#             "main": {
#                 "temp": 294.21,
#                 "feels_like": 293.62,
#                 "temp_min": 293.58,
#                 "temp_max": 294.21,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 924,
#                 "humidity": 48,
#                 "temp_kf": 0.63
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 89
#             },
#             "wind": {
#                 "speed": 6.65,
#                 "deg": 73,
#                 "gust": 9.24
#             },
#             "visibility": 10000,
#             "pop": 0.61,
#             "rain": {
#                 "3h": 0.11
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-08 00:00:00"
#         },
#         {
#             "dt": 1680922800,
#             "main": {
#                 "temp": 291.49,
#                 "feels_like": 290.87,
#                 "temp_min": 291.49,
#                 "temp_max": 291.49,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 925,
#                 "humidity": 57,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 97
#             },
#             "wind": {
#                 "speed": 7.59,
#                 "deg": 91,
#                 "gust": 11.27
#             },
#             "visibility": 10000,
#             "pop": 0.34,
#             "rain": {
#                 "3h": 0.22
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-08 03:00:00"
#         },
#         {
#             "dt": 1680933600,
#             "main": {
#                 "temp": 296.57,
#                 "feels_like": 295.83,
#                 "temp_min": 296.57,
#                 "temp_max": 296.57,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 927,
#                 "humidity": 33,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 82
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 130,
#                 "gust": 7.41
#             },
#             "visibility": 10000,
#             "pop": 0.03,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-08 06:00:00"
#         },
#         {
#             "dt": 1680944400,
#             "main": {
#                 "temp": 300.93,
#                 "feels_like": 299.77,
#                 "temp_min": 300.93,
#                 "temp_max": 300.93,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 926,
#                 "humidity": 21,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 51
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 126,
#                 "gust": 5.62
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-08 09:00:00"
#         },
#         {
#             "dt": 1680955200,
#             "main": {
#                 "temp": 302.14,
#                 "feels_like": 300.58,
#                 "temp_min": 302.14,
#                 "temp_max": 302.14,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 924,
#                 "humidity": 19,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 26
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 93,
#                 "gust": 4.91
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-08 12:00:00"
#         },
#         {
#             "dt": 1680966000,
#             "main": {
#                 "temp": 300.91,
#                 "feels_like": 299.73,
#                 "temp_min": 300.91,
#                 "temp_max": 300.91,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 924,
#                 "humidity": 20,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 7
#             },
#             "wind": {
#                 "speed": 5.82,
#                 "deg": 111,
#                 "gust": 5.48
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-08 15:00:00"
#         },
#         {
#             "dt": 1680976800,
#             "main": {
#                 "temp": 297.07,
#                 "feels_like": 296.33,
#                 "temp_min": 297.07,
#                 "temp_max": 297.07,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 926,
#                 "humidity": 31,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 20
#             },
#             "wind": {
#                 "speed": 7,
#                 "deg": 139,
#                 "gust": 10.79
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-08 18:00:00"
#         },
#         {
#             "dt": 1680987600,
#             "main": {
#                 "temp": 294.61,
#                 "feels_like": 293.8,
#                 "temp_min": 294.61,
#                 "temp_max": 294.61,
#                 "pressure": 1018,
#                 "sea_level": 1018,
#                 "grnd_level": 926,
#                 "humidity": 38,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 4.7,
#                 "deg": 138,
#                 "gust": 8.98
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-08 21:00:00"
#         },
#         {
#             "dt": 1680998400,
#             "main": {
#                 "temp": 292.98,
#                 "feels_like": 291.98,
#                 "temp_min": 292.98,
#                 "temp_max": 292.98,
#                 "pressure": 1017,
#                 "sea_level": 1017,
#                 "grnd_level": 925,
#                 "humidity": 37,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 3.49,
#                 "deg": 129,
#                 "gust": 4.18
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-09 00:00:00"
#         },
#         {
#             "dt": 1681009200,
#             "main": {
#                 "temp": 291.79,
#                 "feels_like": 290.83,
#                 "temp_min": 291.79,
#                 "temp_max": 291.79,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 926,
#                 "humidity": 43,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 3.3,
#                 "deg": 140,
#                 "gust": 3.44
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-09 03:00:00"
#         },
#         {
#             "dt": 1681020000,
#             "main": {
#                 "temp": 297.8,
#                 "feels_like": 297.05,
#                 "temp_min": 297.8,
#                 "temp_max": 297.8,
#                 "pressure": 1019,
#                 "sea_level": 1019,
#                 "grnd_level": 928,
#                 "humidity": 28,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 6.45,
#                 "deg": 135,
#                 "gust": 9.02
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-09 06:00:00"
#         },
#         {
#             "dt": 1681030800,
#             "main": {
#                 "temp": 302.17,
#                 "feels_like": 300.63,
#                 "temp_min": 302.17,
#                 "temp_max": 302.17,
#                 "pressure": 1016,
#                 "sea_level": 1016,
#                 "grnd_level": 926,
#                 "humidity": 20,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 7.11,
#                 "deg": 127,
#                 "gust": 7.11
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-09 09:00:00"
#         },
#         {
#             "dt": 1681041600,
#             "main": {
#                 "temp": 303.98,
#                 "feels_like": 302.02,
#                 "temp_min": 303.98,
#                 "temp_max": 303.98,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 924,
#                 "humidity": 18,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 8
#             },
#             "wind": {
#                 "speed": 5.98,
#                 "deg": 126,
#                 "gust": 5.69
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-09 12:00:00"
#         },
#         {
#             "dt": 1681052400,
#             "main": {
#                 "temp": 302.76,
#                 "feels_like": 301.05,
#                 "temp_min": 302.76,
#                 "temp_max": 302.76,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 923,
#                 "humidity": 19,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 66
#             },
#             "wind": {
#                 "speed": 5.76,
#                 "deg": 123,
#                 "gust": 6.26
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-09 15:00:00"
#         },
#         {
#             "dt": 1681063200,
#             "main": {
#                 "temp": 299.3,
#                 "feels_like": 299.3,
#                 "temp_min": 299.3,
#                 "temp_max": 299.3,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 923,
#                 "humidity": 23,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 67
#             },
#             "wind": {
#                 "speed": 4.69,
#                 "deg": 108,
#                 "gust": 8.18
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-09 18:00:00"
#         },
#         {
#             "dt": 1681074000,
#             "main": {
#                 "temp": 298.57,
#                 "feels_like": 297.74,
#                 "temp_min": 298.57,
#                 "temp_max": 298.57,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 922,
#                 "humidity": 22,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 76
#             },
#             "wind": {
#                 "speed": 7.5,
#                 "deg": 107,
#                 "gust": 13.62
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-09 21:00:00"
#         },
#         {
#             "dt": 1681084800,
#             "main": {
#                 "temp": 296.59,
#                 "feels_like": 295.67,
#                 "temp_min": 296.59,
#                 "temp_max": 296.59,
#                 "pressure": 1012,
#                 "sea_level": 1012,
#                 "grnd_level": 921,
#                 "humidity": 26,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 4.48,
#                 "deg": 131,
#                 "gust": 6.95
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-10 00:00:00"
#         },
#         {
#             "dt": 1681095600,
#             "main": {
#                 "temp": 295.3,
#                 "feels_like": 294.48,
#                 "temp_min": 295.3,
#                 "temp_max": 295.3,
#                 "pressure": 1013,
#                 "sea_level": 1013,
#                 "grnd_level": 922,
#                 "humidity": 35,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 92
#             },
#             "wind": {
#                 "speed": 3.71,
#                 "deg": 155,
#                 "gust": 4.01
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-10 03:00:00"
#         },
#         {
#             "dt": 1681106400,
#             "main": {
#                 "temp": 299.76,
#                 "feels_like": 299.76,
#                 "temp_min": 299.76,
#                 "temp_max": 299.76,
#                 "pressure": 1014,
#                 "sea_level": 1014,
#                 "grnd_level": 923,
#                 "humidity": 31,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 7.46,
#                 "deg": 163,
#                 "gust": 10.09
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-10 06:00:00"
#         },
#         {
#             "dt": 1681117200,
#             "main": {
#                 "temp": 302.69,
#                 "feels_like": 301.21,
#                 "temp_min": 302.69,
#                 "temp_max": 302.69,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 922,
#                 "humidity": 25,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 8.31,
#                 "deg": 165,
#                 "gust": 8.37
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-10 09:00:00"
#         },
#         {
#             "dt": 1681128000,
#             "main": {
#                 "temp": 302.55,
#                 "feels_like": 301.14,
#                 "temp_min": 302.55,
#                 "temp_max": 302.55,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 920,
#                 "humidity": 26,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 8.63,
#                 "deg": 167,
#                 "gust": 9.41
#             },
#             "visibility": 10000,
#             "pop": 0.26,
#             "rain": {
#                 "3h": 0.2
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-10 12:00:00"
#         },
#         {
#             "dt": 1681138800,
#             "main": {
#                 "temp": 300.84,
#                 "feels_like": 300.03,
#                 "temp_min": 300.84,
#                 "temp_max": 300.84,
#                 "pressure": 1009,
#                 "sea_level": 1009,
#                 "grnd_level": 919,
#                 "humidity": 30,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 6.41,
#                 "deg": 149,
#                 "gust": 9.54
#             },
#             "visibility": 10000,
#             "pop": 0.68,
#             "rain": {
#                 "3h": 0.56
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-10 15:00:00"
#         },
#         {
#             "dt": 1681149600,
#             "main": {
#                 "temp": 296.87,
#                 "feels_like": 296.47,
#                 "temp_min": 296.87,
#                 "temp_max": 296.87,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 920,
#                 "humidity": 45,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 7.89,
#                 "deg": 177,
#                 "gust": 11.77
#             },
#             "visibility": 10000,
#             "pop": 0.93,
#             "rain": {
#                 "3h": 0.88
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-10 18:00:00"
#         },
#         {
#             "dt": 1681160400,
#             "main": {
#                 "temp": 294.59,
#                 "feels_like": 294.28,
#                 "temp_min": 294.59,
#                 "temp_max": 294.59,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 919,
#                 "humidity": 57,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.24,
#                 "deg": 185,
#                 "gust": 9.67
#             },
#             "visibility": 10000,
#             "pop": 0.89,
#             "rain": {
#                 "3h": 4.12
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-10 21:00:00"
#         },
#         {
#             "dt": 1681171200,
#             "main": {
#                 "temp": 294.35,
#                 "feels_like": 294.09,
#                 "temp_min": 294.35,
#                 "temp_max": 294.35,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 918,
#                 "humidity": 60,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 5.55,
#                 "deg": 188,
#                 "gust": 8.74
#             },
#             "visibility": 10000,
#             "pop": 0.93,
#             "rain": {
#                 "3h": 2.55
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 00:00:00"
#         },
#         {
#             "dt": 1681182000,
#             "main": {
#                 "temp": 293.12,
#                 "feels_like": 292.97,
#                 "temp_min": 293.12,
#                 "temp_max": 293.12,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 919,
#                 "humidity": 69,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 185,
#                 "gust": 7.45
#             },
#             "visibility": 10000,
#             "pop": 0.86,
#             "rain": {
#                 "3h": 1.98
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 03:00:00"
#         },
#         {
#             "dt": 1681192800,
#             "main": {
#                 "temp": 297.35,
#                 "feels_like": 297.05,
#                 "temp_min": 297.35,
#                 "temp_max": 297.35,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 920,
#                 "humidity": 47,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 90
#             },
#             "wind": {
#                 "speed": 7.87,
#                 "deg": 172,
#                 "gust": 10.57
#             },
#             "visibility": 10000,
#             "pop": 0.88,
#             "rain": {
#                 "3h": 0.21
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 06:00:00"
#         },
#         {
#             "dt": 1681203600,
#             "main": {
#                 "temp": 302.95,
#                 "feels_like": 301.79,
#                 "temp_min": 302.95,
#                 "temp_max": 302.95,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 919,
#                 "humidity": 31,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 9
#             },
#             "wind": {
#                 "speed": 9.65,
#                 "deg": 181,
#                 "gust": 10.15
#             },
#             "visibility": 10000,
#             "pop": 0.2,
#             "rain": {
#                 "3h": 0.15
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 09:00:00"
#         },
#         {
#             "dt": 1681214400,
#             "main": {
#                 "temp": 306.3,
#                 "feels_like": 304.32,
#                 "temp_min": 306.3,
#                 "temp_max": 306.3,
#                 "pressure": 1004,
#                 "sea_level": 1004,
#                 "grnd_level": 916,
#                 "humidity": 21,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 14
#             },
#             "wind": {
#                 "speed": 7.98,
#                 "deg": 183,
#                 "gust": 7.64
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 12:00:00"
#         },
#         {
#             "dt": 1681225200,
#             "main": {
#                 "temp": 306.11,
#                 "feels_like": 303.98,
#                 "temp_min": 306.11,
#                 "temp_max": 306.11,
#                 "pressure": 1003,
#                 "sea_level": 1003,
#                 "grnd_level": 915,
#                 "humidity": 19,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 20
#             },
#             "wind": {
#                 "speed": 7.01,
#                 "deg": 215,
#                 "gust": 9.97
#             },
#             "visibility": 10000,
#             "pop": 0.03,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-11 15:00:00"
#         },
#         {
#             "dt": 1681236000,
#             "main": {
#                 "temp": 293.83,
#                 "feels_like": 293.65,
#                 "temp_min": 293.83,
#                 "temp_max": 293.83,
#                 "pressure": 1011,
#                 "sea_level": 1011,
#                 "grnd_level": 919,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 60
#             },
#             "wind": {
#                 "speed": 11.99,
#                 "deg": 5,
#                 "gust": 13.45
#             },
#             "visibility": 10000,
#             "pop": 0.57,
#             "rain": {
#                 "3h": 0.34
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 18:00:00"
#         },
#         {
#             "dt": 1681246800,
#             "main": {
#                 "temp": 294.21,
#                 "feels_like": 293.96,
#                 "temp_min": 294.21,
#                 "temp_max": 294.21,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 918,
#                 "humidity": 61,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 98
#             },
#             "wind": {
#                 "speed": 5.16,
#                 "deg": 61,
#                 "gust": 6.08
#             },
#             "visibility": 10000,
#             "pop": 0.9,
#             "rain": {
#                 "3h": 0.55
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-11 21:00:00"
#         },
#         {
#             "dt": 1681257600,
#             "main": {
#                 "temp": 293.87,
#                 "feels_like": 293.64,
#                 "temp_min": 293.87,
#                 "temp_max": 293.87,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 917,
#                 "humidity": 63,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 84
#             },
#             "wind": {
#                 "speed": 3.94,
#                 "deg": 128,
#                 "gust": 7.49
#             },
#             "visibility": 10000,
#             "pop": 0.72,
#             "rain": {
#                 "3h": 0.2
#             },
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2023-04-12 00:00:00"
#         },
#         {
#             "dt": 1681268400,
#             "main": {
#                 "temp": 293.7,
#                 "feels_like": 293.53,
#                 "temp_min": 293.7,
#                 "temp_max": 293.7,
#                 "pressure": 1008,
#                 "sea_level": 1008,
#                 "grnd_level": 916,
#                 "humidity": 66,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 34
#             },
#             "wind": {
#                 "speed": 4.59,
#                 "deg": 145,
#                 "gust": 9.18
#             },
#             "visibility": 10000,
#             "pop": 0.1,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 03:00:00"
#         },
#         {
#             "dt": 1681279200,
#             "main": {
#                 "temp": 299.33,
#                 "feels_like": 299.33,
#                 "temp_min": 299.33,
#                 "temp_max": 299.33,
#                 "pressure": 1007,
#                 "sea_level": 1007,
#                 "grnd_level": 917,
#                 "humidity": 42,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 44
#             },
#             "wind": {
#                 "speed": 8.13,
#                 "deg": 169,
#                 "gust": 10.77
#             },
#             "visibility": 10000,
#             "pop": 0.07,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 06:00:00"
#         },
#         {
#             "dt": 1681290000,
#             "main": {
#                 "temp": 305.68,
#                 "feels_like": 304.12,
#                 "temp_min": 305.68,
#                 "temp_max": 305.68,
#                 "pressure": 1003,
#                 "sea_level": 1003,
#                 "grnd_level": 915,
#                 "humidity": 26,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 89
#             },
#             "wind": {
#                 "speed": 11.42,
#                 "deg": 189,
#                 "gust": 14.83
#             },
#             "visibility": 10000,
#             "pop": 0.02,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 09:00:00"
#         },
#         {
#             "dt": 1681300800,
#             "main": {
#                 "temp": 307.62,
#                 "feels_like": 305.51,
#                 "temp_min": 307.62,
#                 "temp_max": 307.62,
#                 "pressure": 998,
#                 "sea_level": 998,
#                 "grnd_level": 912,
#                 "humidity": 19,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 94
#             },
#             "wind": {
#                 "speed": 14.85,
#                 "deg": 210,
#                 "gust": 21.63
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 12:00:00"
#         },
#         {
#             "dt": 1681311600,
#             "main": {
#                 "temp": 298.89,
#                 "feels_like": 298.93,
#                 "temp_min": 298.89,
#                 "temp_max": 298.89,
#                 "pressure": 1004,
#                 "sea_level": 1004,
#                 "grnd_level": 914,
#                 "humidity": 54,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 16.08,
#                 "deg": 266,
#                 "gust": 20.39
#             },
#             "visibility": 8806,
#             "pop": 0.65,
#             "rain": {
#                 "3h": 0.62
#             },
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2023-04-12 15:00:00"
#         }
#     ],
#     "city": {
#         "id": 396460,
#         "name": "Khushayb\u012b al \u1e28a\u1e11ar",
#         "coord": {
#             "lat": 25.351,
#             "lon": 41.98
#         },
#         "country": "SA",
#         "population": 0,
#         "timezone": 10800,
#         "sunrise": 1680836264,
#         "sunset": 1680881434
#     }
# }

# %% [markdown]
# ### Subtask 3: Prepare Data for Cleaning
# TODO
# - ✅ Examine the outputted JSON data, and locate the property that holds a **list of weather forecasts**
# - ✅ Save this list of weather forecasts as the variable `forecast_list` below

# %%
forecast_list = prettified_forecast

# %% [markdown]
# ### Subtask 4: Data Extraction
# TODO
# - ✅ Loop through each value within `forecast_list`, and perform the following:
#     - ✅ Using square brackets, extract the following properties into their own variable:
#         - Timestamp
#         - Temperature
#         - "Feels Like" Temperature
#         - Wind Speed
#         - Humidity
#     - ✅ Create a **Dictionary** with key:value pairs for each of the above properties
#     - ✅ Append that dictionary to the `data_list` list variable

# %%
data_list = []
for day in forecast["list"]:
    timestamp = day["dt_txt"]
    temperature = day["main"]["temp"]
    feels_like = day["main"]["feels_like"]
    wind_speed = day["wind"]["speed"]
    humidity = day["main"]["humidity"]
    forecast_dictionary = {
        "timestamp": timestamp,
        "temperature": temperature,
        "feels_like": feels_like,
        "wind_speed": wind_speed,
        "humidity": humidity
    }
    data_list.append(forecast_dictionary)

    # print(timestamp, temperature, feels_like, wind_speed, humidity)

# %% [markdown]
# ### Subtask 5: DataFrame Creation & Munging
# TODO
# - ✅ Using the Pandas DataFrame `.from_records()` method, create a new DataFrame from `data_list`, and save as a variable
# - ✅ Use the appropriate Pandas method to convert the `timestamp` column to DateTime format

# %%
data_list_df = pd.DataFrame(data_list)
print(data_list_df)

data_list_df['timestamp']= pd.to_datetime(data_list_df['timestamp'])
# data_list_df.info()
print(data_list_df)
# Out:
#               timestamp  temperature  feels_like  wind_speed  humidity
# 0   2023-04-07 18:00:00       295.46      294.95        7.19        46
# 1   2023-04-07 21:00:00       294.77      294.29        7.45        50
# 2   2023-04-08 00:00:00       294.21      293.62        6.65        48
# 3   2023-04-08 03:00:00       291.49      290.87        7.59        57
# 4   2023-04-08 06:00:00       296.57      295.83        6.20        33
# 5   2023-04-08 09:00:00       300.93      299.77        6.20        21
# 6   2023-04-08 12:00:00       302.14      300.58        5.10        19
# 7   2023-04-08 15:00:00       300.91      299.73        5.82        20
# 8   2023-04-08 18:00:00       297.07      296.33        7.00        31
# 9   2023-04-08 21:00:00       294.61      293.80        4.70        38
# 10  2023-04-09 00:00:00       292.98      291.98        3.49        37
# 11  2023-04-09 03:00:00       291.79      290.83        3.30        43
# 12  2023-04-09 06:00:00       297.80      297.05        6.45        28
# 13  2023-04-09 09:00:00       302.17      300.63        7.11        20
# 14  2023-04-09 12:00:00       303.98      302.02        5.98        18
# 15  2023-04-09 15:00:00       302.76      301.05        5.76        19
# 16  2023-04-09 18:00:00       299.30      299.30        4.69        23
# 17  2023-04-09 21:00:00       298.57      297.74        7.50        22
# 18  2023-04-10 00:00:00       296.59      295.67        4.48        26
# 19  2023-04-10 03:00:00       295.30      294.48        3.71        35
# 20  2023-04-10 06:00:00       299.76      299.76        7.46        31
# 21  2023-04-10 09:00:00       302.69      301.21        8.31        25
# 22  2023-04-10 12:00:00       302.55      301.14        8.63        26
# 23  2023-04-10 15:00:00       300.84      300.03        6.41        30
# 24  2023-04-10 18:00:00       296.87      296.47        7.89        45
# 25  2023-04-10 21:00:00       294.59      294.28        5.24        57
# 26  2023-04-11 00:00:00       294.35      294.09        5.55        60
# 27  2023-04-11 03:00:00       293.12      292.97        4.10        69
# 28  2023-04-11 06:00:00       297.35      297.05        7.87        47
# 29  2023-04-11 09:00:00       302.95      301.79        9.65        31
# 30  2023-04-11 12:00:00       306.30      304.32        7.98        21
# 31  2023-04-11 15:00:00       306.11      303.98        7.01        19
# 32  2023-04-11 18:00:00       293.83      293.65       11.99        65
# 33  2023-04-11 21:00:00       294.21      293.96        5.16        61
# 34  2023-04-12 00:00:00       293.87      293.64        3.94        63
# 35  2023-04-12 03:00:00       293.70      293.53        4.59        66
# 36  2023-04-12 06:00:00       299.33      299.33        8.13        42
# 37  2023-04-12 09:00:00       305.68      304.12       11.42        26
# 38  2023-04-12 12:00:00       307.62      305.51       14.85        19
# 39  2023-04-12 15:00:00       298.89      298.93       16.08        54
#              timestamp  temperature  feels_like  wind_speed  humidity
# 0  2023-04-07 18:00:00       295.46      294.95        7.19        46
# 1  2023-04-07 21:00:00       294.77      294.29        7.45        50
# 2  2023-04-08 00:00:00       294.21      293.62        6.65        48
# 3  2023-04-08 03:00:00       291.49      290.87        7.59        57
# 4  2023-04-08 06:00:00       296.57      295.83        6.20        33
# 5  2023-04-08 09:00:00       300.93      299.77        6.20        21
# 6  2023-04-08 12:00:00       302.14      300.58        5.10        19
# 7  2023-04-08 15:00:00       300.91      299.73        5.82        20
# 8  2023-04-08 18:00:00       297.07      296.33        7.00        31
# 9  2023-04-08 21:00:00       294.61      293.80        4.70        38
# 10 2023-04-09 00:00:00       292.98      291.98        3.49        37
# 11 2023-04-09 03:00:00       291.79      290.83        3.30        43
# 12 2023-04-09 06:00:00       297.80      297.05        6.45        28
# 13 2023-04-09 09:00:00       302.17      300.63        7.11        20
# 14 2023-04-09 12:00:00       303.98      302.02        5.98        18
# 15 2023-04-09 15:00:00       302.76      301.05        5.76        19
# 16 2023-04-09 18:00:00       299.30      299.30        4.69        23
# 17 2023-04-09 21:00:00       298.57      297.74        7.50        22
# 18 2023-04-10 00:00:00       296.59      295.67        4.48        26
# 19 2023-04-10 03:00:00       295.30      294.48        3.71        35
# 20 2023-04-10 06:00:00       299.76      299.76        7.46        31
# 21 2023-04-10 09:00:00       302.69      301.21        8.31        25
# 22 2023-04-10 12:00:00       302.55      301.14        8.63        26
# 23 2023-04-10 15:00:00       300.84      300.03        6.41        30
# 24 2023-04-10 18:00:00       296.87      296.47        7.89        45
# 25 2023-04-10 21:00:00       294.59      294.28        5.24        57
# 26 2023-04-11 00:00:00       294.35      294.09        5.55        60
# 27 2023-04-11 03:00:00       293.12      292.97        4.10        69
# 28 2023-04-11 06:00:00       297.35      297.05        7.87        47
# 29 2023-04-11 09:00:00       302.95      301.79        9.65        31
# 30 2023-04-11 12:00:00       306.30      304.32        7.98        21
# 31 2023-04-11 15:00:00       306.11      303.98        7.01        19
# 32 2023-04-11 18:00:00       293.83      293.65       11.99        65
# 33 2023-04-11 21:00:00       294.21      293.96        5.16        61
# 34 2023-04-12 00:00:00       293.87      293.64        3.94        63
# 35 2023-04-12 03:00:00       293.70      293.53        4.59        66
# 36 2023-04-12 06:00:00       299.33      299.33        8.13        42
# 37 2023-04-12 09:00:00       305.68      304.12       11.42        26
# 38 2023-04-12 12:00:00       307.62      305.51       14.85        19
# 39 2023-04-12 15:00:00       298.89      298.93       16.08        54

# %% [markdown]
# ### Subtask 6: Export Data to JSON
# TODO
# - ✅ Use the appropriate Pandas function to export your DataFrame to **JSON format**
#     - Name your file `forecastdata.json`
#     - Use the orientation **`records`** when outputting
#     - Include the argument **`date_format="iso"`** to ensure all DateTime values are exported correctly!

# %%
forecastdata = data_list_df

# data_list_df.to_json(r'C:\Users\daryl\OneDrive\Desktop\devCodeCamp\Week18-Weather Forecast API LAB', date_format="iso")
forecastdata.to_json("forecast.json", date_format="iso", orient='records')

# %% [markdown]
# ### Subtask 7: Data Visualization with Tableau
# TODO
# - ✅ Within Tableau, import your `forecastdata.json` file
# - ✅ Ensure that the `timestamp` column has been converted to Date & Time
# - ✅ Create **two** visualizations exploring trends and patterns in your area's 5-day forecast
# - ✅ Save these visualizations to Tableau Public, then download a copy of the workbook, and include it in your repository folder
